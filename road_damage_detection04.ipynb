# %% [markdown]
# <a href="https://colab.research.google.com/github/Spykabore15/road-damage-detection-yolo/blob/main/road_damage_detection04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Road damage detection with YOLO V8 using dataset V1**

# %% [markdown]
# ### Dependencies installation and Configuration

# %%
# !pip install mlflow roboflow ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 99.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.8/76.8 kB 8.3 MB/s eta 0:00:00
# ...

# %%
import mlflow
import time
import json
from pathlib import Path
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import userdata
from roboflow import Roboflow
# Import the dataset from roboflow
ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')

rf = Roboflow(api_key = ROBOFLOW_API_KEY)
project = rf.workspace("alpha-nydx8").project("road-damage-detection-v2-xg6by")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Road-Damage-Detection-v2-1 in yolov8:: 100%|██████████| 6405/6405 [00:00<00:00, 7258.74it/s]

# %%
# !yolo settings mlflow=True
# Out:
# ✅ Updated 'mlflow=True'
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
#mlflow logging conf

mlflow_uri = "/content/drive/MyDrive/YOLOv8_RoadDamage_NoAugm/01 Training Logs/YOLOv8s Dataset V2 (7 class) "
experiment_name = "yolov8s using dataset V2 on yolov8s.pt"

#model config
model = YOLO("yolov8s.pt")

# %%
mlflow.set_tracking_uri(mlflow_uri)
mlflow.set_experiment(experiment_name)
# Out:
# Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
# 2025/11/21 02:58:23 INFO mlflow.tracking.fluent: Experiment with name 'yolov8s using dataset V2 on yolov8s.pt' does not exist. Creating a new experiment.
# <Experiment: artifact_location=('/content/drive/MyDrive/YOLOv8_RoadDamage_NoAugm/01 Training Logs/YOLOv8s '
#  'Dataset V2 (7 class) /165890234032675565'), creation_time=1763693903182, experiment_id='165890234032675565', last_update_time=1763693903182, lifecycle_stage='active', name='yolov8s using dataset V2 on yolov8s.pt', tags={}>

# %% [markdown]
# ### Model Training

# %%
results = model.train(
    data = "/content/Road-Damage-Detection-v2-1/data.yaml",
    epochs = 100,
    batch = 16,
    imgsz = 640,
    save_period = 10,
    patience = 10,
    verbose = True
)

print("________________TRAINING COMPLETE______________")
# Out:
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# ### Model Testing

# %%
print("\n" + "=" * 60)
print("VALIDATION ON THE TEST SET")
print("=" * 60)

# Load the best model
best_model_path = "/content/runs/detect/train2/weights/best.pt"

best_model = YOLO(best_model_path)

# Validation
metrics = best_model.val()

# Print the metrics
print(f"\nFinal metrics:")
print(f"  mAP@50:     {metrics.box.map50:.4f}")
print(f"  mAP@50-95:  {metrics.box.map:.4f}")
print(f"  Precision:  {metrics.box.mp:.4f}")
print(f"  Recall:     {metrics.box.mr:.4f}")
# Out:
# ...
# VALIDATION ON THE TEST SET
# ...
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# Model summary (fused): 72 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1878.2±572.0 MB/s, size: 66.9 KB)
# val: Scanning /content/Road-Damage-Detection-v2-1/valid/labels.cache... 641 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 641/641 1.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 41/41 6.3it/s 6.5s
#                    all        641       1646      0.744      0.606      0.669      0.415
#        alligator crack        213        264      0.877      0.545      0.738      0.425
#         lane line blur         90        122      0.503      0.287      0.352      0.174
#     longitudinal crack        364        674      0.812      0.667      0.763      0.475
# ...

# %% [markdown]
# ### Model Deployment

# %%
MODEL_PATH = '/content/runs/detect/train2'
project.version(1).deploy(model_type='yolov8', model_path = MODEL_PATH)
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.3.229, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.
